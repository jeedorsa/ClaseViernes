# %% [markdown]
# <a href="https://colab.research.google.com/github/jeedorsa/ClaseViernes/blob/main/ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## HOla mundo

# %%
x=1

# %% [markdown]
# ## prueba2
